# %% [markdown]
# # 🎓 Python for ML/AI - Learning Path
#
# ## Welcome!
#
# This series of interactive notebooks will teach you Python for Machine Learning and AI. Since you have C experience, we'll highlight the key differences.
#
# ---
#
# ## 📚 Notebook Series
#
# ### Foundation (Start Here!)
#
# | # | Notebook | Topics | Time |
# |---|----------|--------|------|
# | 01 | **Python Basics** | Variables, operators, control flow, functions | ~1-2 hours |
# | 02 | **Data Structures** | Lists, dictionaries, tuples, sets | ~1-2 hours |
# | 03 | **NumPy Basics** | Arrays, vectorized ops, matrix math | ~2-3 hours |
#
# ### Coming Soon
# - 04 - Pandas (Data Manipulation)
# - 05 - Matplotlib (Visualization)
# - 06 - Scikit-Learn (ML Algorithms)
# - 07 - PyTorch (Deep Learning)
#
# ---
#
# ## 🚀 How to Use
#
# 1. **Run cells** with `Shift + Enter`
# 2. **Modify code** and experiment - you can't break anything!
# 3. **Complete exercises** marked with ✏️
# 4. **Move to next notebook** when you feel comfortable
#
# ---
#
# ## 💡 Tips for C Programmers
#
# | C | Python |
# |---|--------|
# | `int x = 10;` | `x = 10` |
# | `{ }` blocks | Indentation |
# | `;` end lines | No semicolons |
# | `&&, \|\|, !` | `and, or, not` |
# | `x++` | `x += 1` |
# | `printf()` | `print()` |
#
# ---
#
# ## Let's Start!
#
# Open **01_python_basics.ipynb** and begin your journey! 🐍
